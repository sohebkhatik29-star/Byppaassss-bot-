# %% [markdown]
# # 🚀 Universal Auto-Bypass Bot (Google Colab Edition)
# ### Headless Chrome + Cloudflare Solver for vplink, earnlinks, gplinks & 1300+ shorteners!
#
# ---

# %%
import os

# Set Bot Token
os.environ['BOT_TOKEN'] = '8672754516:AAG_xII5WT-BWho_-sAIEMFjtdBvKH35r-8'
os.environ['PORT'] = '8000'

# Install dependencies & Playwright Chrome
# !pip install -q pyTelegramBotAPI playwright httpx flask pyyaml cloudscraper
# !playwright install chromium --with-deps

# Clone repository & start bot
# !rm -rf Byppaassss-bot-
# !git clone https://github.com/sohebkhatik29-star/Byppaassss-bot-.git
# %cd Byppaassss-bot-/python_bot

print('🚀 Starting Telegram Bypass Bot on Google Colab...')
# !python3 bot.py
