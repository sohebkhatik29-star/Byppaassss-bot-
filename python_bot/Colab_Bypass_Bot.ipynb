# %% [markdown]
# # 🚀 Universal Auto-Bypass Bot (Google Colab Edition)
# ### Complete Headless Chrome + Cloudflare Solver for vplink, earnlinks, gplinks & 1300+ shorteners!
#
# ---

# %% [markdown]
# ### Step 1: Install Chrome & Dependencies (Runs in 30 seconds)

# %%
# !apt-get update -qq
# !apt-get install -y -qq wget curl unzip
# !pip install -q playwright python-telegram-bot httpx flask pyyaml cloudscraper
# !playwright install chromium --with-deps

# %% [markdown]
# ### Step 2: Clone Bot Repository

# %%
# !rm -rf Byppaassss-bot-
# !git clone https://github.com/sohebkhatik29-star/Byppaassss-bot-.git
# %cd Byppaassss-bot-/python_bot

# %% [markdown]
# ### Step 3: Run Bot with Your Telegram Bot Token

# %%
import os

# Yaha apna Bot Token daalein (BotFather wala):
os.environ['BOT_TOKEN'] = '7891727763:AAGX3Zqj_X6g6n2a3y5j9w1x8z7v6u5t4s3'
os.environ['PORT'] = '8000'

# Optional proxy (agar use karna ho):
# os.environ['PROXY_URL'] = 'http://mgrozljb-rotate:7gbnqml2nydz@p.webshare.io:80'

print('🚀 Starting Telegram Bypass Bot on Google Colab...')
# !python3 bot.py
